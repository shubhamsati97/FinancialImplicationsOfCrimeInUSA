# %%
data_file = "./2022_HC_NATIONAL_MASTER_FILE_ENC.txt"
csv_arrest_file = "./arrests_national_adults.csv"

# %%
data = pd.read_csv(csv_arrest_file)
data.head()
# Out:
#      id  state_abbr  year offense_code        offense_name  agencies  \
# 0  1009         NaN  2016    ASR_ARSON               Arson     13310
# 1  1010         NaN  2016      ASR_AST  Aggravated Assault     13310
# 2  1011         NaN  2016  ASR_AST_SMP      Simple Assault     13310
# 3  1012         NaN  2016      ASR_BRG            Burglary     13310
# 4  1013         NaN  2016      ASR_DIS  Disorderly Conduct     13310
#
#    population  total_male  total_female   m_18  ...  f_50_54  f_55_59  \
# 0   264534532        4509          1426    161  ...      102     74.0
# 1   264534532      224176         67016   5780  ...     3996   2343.0
# 2   264534532      570193        213178  14018  ...    12005   6697.0
# 3   264534532      116213         28754   7077  ...     1279    621.0
# 4   264534532      180722         68577   6997  ...     4085   2464.0
#
#    f_60_64   f_65p  race_agencies  race_population   white   black  \
# ...

# %%
import pandas as pd
data = pd.read_csv(csv_arrest_file)
# data.head()
tmp = data[['year','white']]
tmp = tmp.groupby(['year']).agg(['sum'])

tmp.plot()
# temp = data.groupby(['year'])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# define data values 
# temp['white'].pl ot(kind="line")
# plt.xlabel['year']
plt('year', 'white', data=temp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1w/3_zt1l990w5cndfw71q7bc_m0000gn/T/ipykernel_32091/948419822.py in <module>
#       5 # temp['white'].pl ot(kind="line")
#       6 # plt.xlabel['year']
# ----> 7 plt('year', 'white', data=temp)
#
# TypeError: 'module' object is not callable

# %%
plt.plot(temp,y="white")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1w/3_zt1l990w5cndfw71q7bc_m0000gn/T/ipykernel_32091/1177042652.py in <module>
# ----> 1 plt.plot(temp,y="white")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
# ...

# %%
# Implementation of matplotlib function 
	
import matplotlib.pyplot as plt 
import numpy as np 
	
# Fixing random state for reproducibility 
# np.random.seed(19680801) 
	
# create random data 
# xdata = np.random.random([2, 10]) 
xdata = temp["year"]

# sort the data so it makes clean curves 
# xdata.sort() 
# xdata2.sort() 
	
ydata = temp["white"]
# create some y data points 
# ydata1 = xdata1 ** 2
# ydata2 = 1 - xdata2 ** 3
	
# plot the data 
plt.plot(xdata, ydata, color ='tab:blue') 
# plt.plot(xdata2, ydata2, color ='tab:orange') 
	
	
# set the limits 
# plt.xlim([0, 1]) 
# plt.ylim([0, 1]) 

plt.title('matplotlib.pyplot.plot() example 2') 
	
# display the plot 
plt.show()
# Out:
# /Users/rachnakonigari/opt/anaconda3/lib/python3.9/site-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in wrapper(self)
#     190             return converter(self.iloc[0])
# --> 191         raise TypeError(f"cannot convert the series to {converter}")
#     192
#
# TypeError: cannot convert the series to <class 'float'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
row = temp["year"]

# %%
for item in row:
    print(item)
# Out:
# (1994, 616    1994
# 617    1994
# 618    1994
# 619    1994
# 620    1994
# 621    1994
# 622    1994
# 623    1994
# 624    1994
# 625    1994
# 626    1994
# 627    1994
# 628    1994
# 629    1994
# 630    1994
# 631    1994
# 632    1994
# 633    1994
# 634    1994
# 635    1994
# 636    1994
# 637    1994
# 638    1994
# 639    1994
# 640    1994
# 641    1994
# 642    1994
# 643    1994
# Name: year, dtype: int64)
# (1995, 588    1995
# 589    1995
# 590    1995
# 591    1995
# 592    1995
# 593    1995
# 594    1995
# 595    1995
# 596    1995
# 597    1995
# 598    1995
# 599    1995
# 600    1995
# 601    1995
# 602    1995
# 603    1995
# 604    1995
# 605    1995
# 606    1995
# 607    1995
# 608    1995
# 609    1995
# 610    1995
# 611    1995
# 612    1995
# 613    1995
# 614    1995
# 615    1995
# Name: year, dtype: int64)
# (1996, 560    1996
# 561    1996
# 562    1996
# 563    1996
# 564    1996
# 565    1996
# 566    1996
# 567    1996
# 568    1996
# ...
